# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("Book3.csv")
x=df[['X']] #[[]]to make x 2d means dataframe to insert in linear regression bcz it gives error if we pass 1d array
y=df['Y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
x_train
# Out:
#      X
# 6   22
# 8   19
# 2   18
# 10  24
# 5   22
# 11  11
# 14  23
# 1   23
# 0   15
# 4   24
# 13  16
# 9   16

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr
# Out:
# LinearRegression()

# %%
#here y is target column means which is to be predicted
# and x is features means input data on which we have to train
#so x can have multipl values but y has only one value 
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [63.30935252 54.96402878 65.39568345]
# 3     60
# 7     63
# 12    59
# Name: Y, dtype: int64

# %%
x_pred=lr.predict(x_test)
print(x_pred)
print(x_test)
# Out:
# [63.30935252 54.96402878 65.39568345]
#      X
# 3   23
# 7   19
# 12  24

# %%
import numpy as np
np.float = np.float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
# mAE=(1/n)E|Yact-Ypred|
# mSE=(1/n)E(Yact-Ypred)^2
print(mean_absolute_error(y_pred,y_test))
print(mean_squared_error(y_pred,y_test))
print(r2_score(y_pred,y_test))
print(lr.predict([[24]]))
print(lr.coef_) # (m)slope
print(lr.intercept_)# value of c in y=Mx+C
# Out:
# 5.913669064748201
# 38.811138139847834
# -0.9106590793273315
# [65.39568345]
# [2.08633094]
# 15.323741007194272

# %%
data = pd.DataFrame({'length':[18,20,10,12,18,11],
                    'width':[20,20,10,11,19,10],
                    'type':['Big','Big','Normal','Big','Normal','Big']})
data
# Out:
#    length  width    type
# 0      18     20     Big
# 1      20     20     Big
# 2      10     10  Normal
# 3      12     11     Big
# 4      18     19  Normal
# 5      11     10     Big

# %%
data['Area']=data['length']*data['width']
data
# Out:
#    length  width    type  Area
# 0      18     20     Big   360
# 1      20     20     Big   400
# 2      10     10  Normal   100
# 3      12     11     Big   132
# 4      18     19  Normal   342
# 5      11     10     Big   110

# %%
df=pd.get_dummies(data=data)
df
# Out:
#    length  width  Area  type_Big  type_Normal
# 0      18     20   360         1            0
# 1      20     20   400         1            0
# 2      10     10   100         0            1
# 3      12     11   132         1            0
# 4      18     19   342         0            1
# 5      11     10   110         1            0

# %%
import pandas as pd
df=pd.DataFrame({'Area':[4720,2430,4368,3969,6142,7912],
                'price':[2360000,1215000,2184000,1984500,3071000,3956000]})
df
# Out:
#    Area    price
# 0  4720  2360000
# 1  2430  1215000
# 2  4368  2184000
# 3  3969  1984500
# 4  6142  3071000
# 5  7912  3956000

# %%
df['price']=np.where(df['price']>3000000,'High',np.where(df['price']<2000000,'Low','Medium'))
df
# Out:
#    Area   price
# 0  4720  Medium
# 1  2430     Low
# 2  4368  Medium
# 3  3969     Low
# 4  6142    High
# 5  7912    High

# %%
df=pd.read_csv('Marksheet.csv')
df=df.loc[df['Roll No']==106]
df
# Out:
#     sr no Branch  Enrolment No                            Name  Roll No Div  \
# 27     28     CE  2.300220e+13  CHUDASAMA ASHUTOSH JASVANTBHAI      106  A3
#
#    Mentor Name  TEST-1 MARKS  TEST-2 MARKS TEST-3 MARKS TEST-4 MARKS
# 27         DVP          20.0          23.0         13.5           20

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Marksheet.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sr no         302 non-null    int64
#  1   Branch        302 non-null    object
#  2   Enrolment No  302 non-null    float64
#  3   Name          302 non-null    object
#  4   Roll No       302 non-null    int64
#  5   Div           302 non-null    object
#  6   Mentor Name   301 non-null    object
#  7   TEST-1 MARKS  302 non-null    float64
#  8   TEST-2 MARKS  302 non-null    float64
#  9   TEST-3 MARKS  302 non-null    object
#  10  TEST-4 MARKS  302 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 26.1+ KB

# %%
df.loc[df['TEST-3 MARKS']=='AB','TEST-3 MARKS']=0
df.loc[df['TEST-4 MARKS']=='AB','TEST-4 MARKS']=0
df.info()
df['TEST-3 MARKS']=df['TEST-3 MARKS'].astype('float64')
df['TEST-4 MARKS']=df['TEST-4 MARKS'].astype('float64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sr no         302 non-null    int64
#  1   Branch        302 non-null    object
#  2   Enrolment No  302 non-null    float64
#  3   Name          302 non-null    object
#  4   Roll No       302 non-null    int64
#  5   Div           302 non-null    object
#  6   Mentor Name   301 non-null    object
#  7   TEST-1 MARKS  302 non-null    float64
#  8   TEST-2 MARKS  302 non-null    float64
#  9   TEST-3 MARKS  302 non-null    object
#  10  TEST-4 MARKS  302 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 26.1+ KB

# %%
df['Total Marks']=df['TEST-1 MARKS']+df['TEST-2 MARKS']+df['TEST-3 MARKS']+df['TEST-4 MARKS']

# %%
for i in df['Div'].unique():
    print(i,df.loc[df['Div']==i,'Total Marks'].mean())
# Out:
# A4 74.38571428571429
# A3 79.45714285714286
# A5 70.55714285714286
# A2 82.94594594594595
# A1 92.1891891891892
# A6 58.43055555555556
# A7 49.86363636363637
# A8 78.41071428571429
# A9 57.84615384615385

# %%
df['grade']=np.where(df['Total Marks']>85,'A',
            np.where(df['Total Marks']>75,'B',
            np.where(df['Total Marks']>65,'C',
            np.where(df['Total Marks']>50,'D',
            np.where(df['Total Marks']>35,'E','F')))))
df
# Out:
#      sr no Branch  Enrolment No                            Name  Roll No Div  \
# 0        1     CE  2.200220e+13  KATHIRIYA VRAJKUMAR ASHVINBHAI      110  A4
# 1        2     CE  2.300220e+13       AGRAVAT SAHIL RAJARAMBHAI      101  A3
# 2        3     CE  2.300220e+13      BALAR RAGHUBHAI SURESHBHAI      162  A5
# 3        4     CE  2.300220e+13   BALESANA HASSANBHAI YUNUSBHAI      122  A4
# 4        5     CE  2.300220e+13      BAMBHROLIYA HIT NARESHBHAI       87  A3
# ..     ...    ...           ...                             ...      ...  ..
# 297    299   AIDS  2.400220e+13                 SHELADIYA HARSH       41  A9
# 298    300   AIDS  2.400220e+13                     HET THESIYA       43  A9
# 299    301   AIDS  2.400220e+13       VAIDYA YOGANSHU VIRENBHAI       30  A9
# 300    302   AIDS  2.400220e+13           VIRJA DEEP BHARATBHAI       35  A9
# 301    303   AIDS  2.400220e+13               VORA MAHAMMADKAIF       49  A9
#
# ...

# %%
import matplotlib.pyplot as plt
x=df[['TEST-1 MARKS']]
y=df['Total Marks']
rs=range(0,51)
r2_scores=[]
for i in rs:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scores.append(r2_score(y_test,y_pred))
    print(lr.coef_) # (m)slope
    print(lr.intercept_)# value of c in y=Mx+C
print(max(r2_scores))
print(np.argmax(r2_scores))
plt.plot(rs,r2_scores)
plt.show()
# Out:
# [3.4628478]
# 1.2624775471015681
# [3.37712613]
# 2.778813272819761
# [3.5751306]
# -0.38521502215908754
# [3.73303606]
# -3.7201369324443903
# [3.42344684]
# 2.0930498394187254
# [3.49506284]
# 1.055268868581038
# [3.45471767]
# 1.43914274754691
# [3.56232755]
# -0.7427123244974752
# [3.60449709]
# -1.2036406309511989
# [3.39391655]
# 2.7205124213211747
# [3.64124202]
# -2.2737287316423362
# [3.4339038]
# 2.5133631208648524
# [3.51322611]
# 0.9871743488323546
# [3.55641397]
# -0.45584288980661825
# [3.55972587]
# -0.20618616479319485
# [3.51070738]
# 0.42514729798681117
# [3.56967277]
# -0.36271778659276777
# [3.51286241]
# 0.33769348720092296
# [3.37840942]
# 3.3677648537525755
# [3.49119709]
# 1.1870233111619086
# [3.50764134]
# 0.699320270091917
# [3.51182697]
# 0.5994087218808346
# [3.536326]
# 0.37522801920948723
# [3.47084293]
# 0.5271289430069714
# [3.62604978]
# -1.7572396720761816
# [3.79257782]
# -5.195547677634906
# [3.76348147]
# -4.945975912764638
# [3.41787579]
# ...

# %%
df=pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df['Age']=2025-df['year']
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner  Age
# ...

# %%
df.drop(['name','year'],axis=1,inplace=True)
df
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner  \
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
#       Age
# 0      18
# ...

# %%
df=pd.get_dummies(df,drop_first=True)
#here dropfirst 
df
# Out:
#       selling_price  km_driven  Age  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0             60000      70000   18            0              0         0
# 1            135000      50000   18            0              0         0
# 2            600000     100000   13            1              0         0
# 3            250000      46000    8            0              0         0
# 4            450000     141000   11            1              0         0
# ...             ...        ...  ...          ...            ...       ...
# 4335         409999      80000   11            1              0         0
# 4336         409999      80000   11            1              0         0
# 4337         110000      83000   16            0              0         0
# 4338         865000      90000    9            1              0         0
# 4339         225000      40000    9            0              0         0
#
#       fuel_Petrol  seller_type_Individual  seller_type_Trustmark Dealer  \
# ...

# %%
df.corr()
# Out:
#                               selling_price  km_driven       Age  fuel_Diesel  \
# selling_price                      1.000000  -0.192289 -0.413922     0.282947
# km_driven                         -0.192289   1.000000  0.419688     0.285396
# Age                               -0.413922   0.419688  1.000000    -0.121424
# fuel_Diesel                        0.282947   0.285396 -0.121424     1.000000
# fuel_Electric                     -0.005095  -0.001372  0.025540    -0.015063
# fuel_LPG                          -0.042434   0.036652  0.051266    -0.072422
# fuel_Petrol                       -0.269453  -0.291139  0.114908    -0.970934
# seller_type_Individual            -0.236798   0.182663  0.173703    -0.035314
# seller_type_Trustmark Dealer       0.110176  -0.089858 -0.100225    -0.007911
# transmission_Manual               -0.530205   0.120226  0.143800    -0.048098
# owner_Fourth & Above Owner        -0.078725   0.097349  0.186361    -0.021054
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
x=df.drop('selling_price',axis=1)
y=df['selling_price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(lr.coef_)
print(lr.intercept_)
# Out:
# 0.4031303601432117
# 221706.36930930082
# 182146878750.28098
# [-1.00693536e+00 -3.57644422e+04  2.79850785e+05 -6.40119340e+05
#   5.34843662e+04 -2.06973547e+04 -6.98192679e+04  1.69804232e+05
#  -8.91338059e+05  6.13220830e+02 -3.60457137e+04  1.30679820e+05
#  -2.70647518e+04]
# 1728119.4477074072

# %%
df=pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df['Age']=2025-df['year']
l=[]
for i in df['name']:
    l.append(i.split()[0])
df['name']=l
df.drop('year',axis=1,inplace=True)
df=pd.get_dummies(df,drop_first=True)
df.corr()
x=df.drop('selling_price',axis=1)
y=df['selling_price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)#42 is for this model but we did 100 to 
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(lr.coef_)
print(lr.intercept_)
# Out:
# 0.7654098933670465
# 170299.4322786873
# 79416392943.55559
# [-1.09322821e+00 -3.87029039e+04  1.07419185e+06  1.80603358e+06
#  -2.01162654e+05  8.59209471e+04 -2.79079386e+05 -1.68903034e+05
#  -2.89041392e+05 -5.41375766e+02  5.58182287e+02 -6.88623818e+04
#   7.12862571e+05  1.38546508e+06  7.89988739e+05 -7.21774995e-09
#   2.66428136e+06  9.08628446e+05  3.23841470e+04 -9.29434373e+04
#   1.83964412e+06  4.68943809e+05 -6.83847826e+04  1.17869009e+05
#  -1.83145152e+05 -8.54644565e+04 -1.68962744e+05  3.66174348e+05
#  -1.05484917e+05  1.81544748e+06  2.03708930e+05 -4.44037709e+05
#   5.81563488e+04  2.08292986e+04 -1.14586475e+04  2.49761757e+05
#  -3.23549826e+05  1.74366614e+04 -4.20877439e+04  1.41942914e+05
#  -2.19329327e+04]
# 1233086.4268688816

# %%
df=pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df['Age']=2025-df['year']
df.drop('year',axis=1,inplace=True)
df=pd.get_dummies(df,drop_first=True)
df.corr()
x=df.drop('selling_price',axis=1)
y=df['selling_price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=24)#42 is for this model but we did 100 to 
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(lr.coef_)
print(lr.intercept_)
# Out:
# 0.8174646169616546
# 98852.56090366516
# 43703861138.540146
# [-6.11269974e-01 -2.72247338e+04  4.86762173e+04 ... -1.68470174e+04
#   1.37559479e+05 -2.74233536e+04]
# 1602896.9192763795

# %%
df=pd.read_csv("insurance.csv")
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      4
# charges     0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest  16884.92400
# 1      18    male   33.77         1     no  southeast   1725.55230
# 2      28    male      33         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest  10600.54830
# 1334   18  female   31.92         0     no  northeast   2205.98080
# 1335   18  female   36.85         0     no  southeast   1629.83350
# 1336   21  female    25.8         0     no  southwest   2007.94500
# 1337   61  female   29.07         0    yes  northwest  29141.36030
#
# [1334 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female    27.9         0    yes  southwest  16884.92400
# 1      18    male   33.77         1     no  southeast   1725.55230
# 2      28    male      33         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male   28.88         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male   30.97         3     no  northwest  10600.54830
# 1334   18  female   31.92         0     no  northeast   2205.98080
# 1335   18  female   36.85         0     no  southeast   1629.83350
# 1336   21  female    25.8         0     no  southwest   2007.94500
# 1337   61  female   29.07         0    yes  northwest  29141.36030
#
# [1333 rows x 7 columns]

# %%
df=df[df['bmi']!="-"]
df['bmi']=df['bmi'].astype('float')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1333 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1333 non-null   int64
#  1   gender    1333 non-null   object
#  2   bmi       1333 non-null   float64
#  3   children  1333 non-null   int64
#  4   smoker    1333 non-null   object
#  5   region    1333 non-null   object
#  6   charges   1333 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.3+ KB
# <ipython-input-32-c7f2a41131b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bmi']=df['bmi'].astype('float')
#       age  gender     bmi  children smoker     region      charges
# ...

# %%
q1=df['bmi'].quantile(0.25)
q3=df['bmi'].quantile(0.75)
iqr=q3-q1
lowerbound = q1-1.5*iqr
upperbound = q3+1.5*iqr
df=df[(df['bmi']>=lowerbound) & (df['bmi']<=upperbound)]
print(df)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1324 rows x 7 columns]

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#       age     bmi  children      charges  gender_male  smoker_yes  \
# 0      19  27.900         0  16884.92400            0           1
# 1      18  33.770         1   1725.55230            1           0
# 2      28  33.000         3   4449.46200            1           0
# 3      33  22.705         0  21984.47061            1           0
# 4      32  28.880         0   3866.85520            1           0
# ...   ...     ...       ...          ...          ...         ...
# 1333   50  30.970         3  10600.54830            1           0
# 1334   18  31.920         0   2205.98080            0           0
# 1335   18  36.850         0   1629.83350            0           0
# 1336   21  25.800         0   2007.94500            0           0
# 1337   61  29.070         0  29141.36030            0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# ...

# %%
x=df.drop('charges',axis=1)
y=df['charges']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=18)#42 is for this model but we did 100 to 
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(lr.coef_)
print(lr.intercept_)
# Out:
# 0.7723064349334688
# 3776.0275150522552
# 29082233.22670253
# [  256.19538618   344.89011489   452.79096234  -127.41326009
#  23560.73089324  -207.69147125  -647.98711528  -977.89411309]
# -12171.809813312828

# %%
rs=range(0,51)
error=[]
for i in rs:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    error.append(mean_absolute_error(y_test,y_pred))
print(min(error))
print(np.argmin(error))
# Out:
# 3776.0275150522552
# 18

# %%
y_pred=lr.predict([[25,37.9,2,1,0,0,0,1]])
print(y_pred)
# Out:
# [7168.48280383]

# %%
x_train
# Out:
#       age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 962    63  35.200         1            0           0                 0
# 22     18  34.100         0            1           0                 0
# 1108   26  30.000         1            1           0                 0
# 1318   35  39.710         4            1           0                 0
# 862    55  33.535         2            0           0                 1
# ...   ...     ...       ...          ...         ...               ...
# 230    42  36.195         1            0           0                 1
# 70     27  24.750         0            0           1                 0
# 133    19  25.555         0            1           0                 1
# 1323   42  40.370         2            0           1                 0
# 109    63  35.090         0            1           1                 0
#
#       region_southeast  region_southwest
# 962                  1                 0
# ...

# %%
import seaborn as sns
df=pd.read_csv("Ice_cream selling data.csv");
x=df[["Temperature (°C)"]]
y=df[["Ice Cream Sales (units)"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=343)#42 is for this model but we did 100 to 
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(lr.coef_)
print(lr.intercept_)
sns.regplot(x*x,y)
# Out:
# 0.1344690889979553
# 5.504406235720141
# 37.012784257363286
# [[-0.67376728]]
# [16.45669408]
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Temperature (°C)', ylabel='Ice Cream Sales (units)'>

# %%
rs=range(0,500)
r2_scores=[]
for i in rs:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scores.append(r2_score(y_test,y_pred))
print(max(r2_scores))
print(np.argmax(r2_scores))
# Out:
# 0.1344690889979553
# 343

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=4)
x_train = poly.fit_transform(x_train)
print(x_train)
x_test=poly.fit_transform(x_test)
# Out:
# [[ 1.00000000e+00 -1.81893761e+00  3.30853403e+00 -6.01801697e+00
#    1.09463974e+01]
#  [ 1.00000000e+00 -3.38952856e-02  1.14889038e-03 -3.89419677e-05
#    1.31994911e-06]
#  [ 1.00000000e+00 -2.67246083e+00  7.14204687e+00 -1.90868405e+01
#    5.10088335e+01]
#  [ 1.00000000e+00 -3.57855372e+00  1.28060467e+01 -4.58271260e+01
#    1.63994832e+02]
#  [ 1.00000000e+00  3.31607252e+00  1.09963370e+01  3.64646508e+01
#    1.20919426e+02]
#  [ 1.00000000e+00  2.47194600e+00  6.11051701e+00  1.51048681e+01
#    3.73384182e+01]
#  [ 1.00000000e+00 -2.65149803e+00  7.03044182e+00 -1.86412027e+01
#    4.94271122e+01]
#  [ 1.00000000e+00 -1.17312327e+00  1.37621820e+00 -1.61447359e+00
#    1.89397654e+00]
#  [ 1.00000000e+00  2.31859124e+00  5.37586534e+00  1.24644343e+01
#    2.88999281e+01]
#  [ 1.00000000e+00  2.78483646e+00  7.75531413e+00  2.15972816e+01
#    6.01448972e+01]
#  [ 1.00000000e+00  8.74905029e-01  7.65458810e-01  6.69703763e-01
#    5.85927190e-01]
# ...

# %%
df=pd.read_csv("Ice_cream selling data.csv");
x=df[["Temperature (°C)"]]
y=df[["Ice Cream Sales (units)"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=150)#42 is for this model but we did 100 to 
poly=PolynomialFeatures(degree=4)
x_train = poly.fit_transform(x_train)
print(x_train)
x_test=poly.fit_transform(x_test)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# [[ 1.00000000e+00  3.33593241e+00  1.11284451e+01  3.71237406e+01
#    1.23842289e+02]
#  [ 1.00000000e+00 -3.57855372e+00  1.28060467e+01 -4.58271260e+01
#    1.63994832e+02]
#  [ 1.00000000e+00 -2.65228679e+00  7.03462523e+00 -1.86578436e+01
#    4.94859522e+01]
#  [ 1.00000000e+00 -3.61564977e-02  1.30729232e-03 -4.72671119e-05
#    1.70901322e-06]
#  [ 1.00000000e+00  8.74905029e-01  7.65458810e-01  6.69703763e-01
#    5.85927190e-01]
#  [ 1.00000000e+00 -1.32637898e+00  1.75928121e+00 -2.33347362e+00
#    3.09507037e+00]
#  [ 1.00000000e+00  6.88780908e-01  4.74419139e-01  3.26770845e-01
#    2.25073519e-01]
#  [ 1.00000000e+00  3.27004407e+00  1.06931882e+01  3.49671967e+01
#    1.14344274e+02]
#  [ 1.00000000e+00 -3.94966109e+00  1.55998227e+01 -6.16140128e+01
#    2.43354469e+02]
#  [ 1.00000000e+00 -4.66226268e+00  2.17366933e+01 -1.01342174e+02
#    4.72483834e+02]
#  [ 1.00000000e+00 -2.65149803e+00  7.03044182e+00 -1.86412027e+01
#    4.94271122e+01]
# ...

# %%
rs=range(0,500)
r2_scores=[]
for i in rs:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    poly=PolynomialFeatures(degree=8)
    x_train = poly.fit_transform(x_train)
    x_test=poly.fit_transform(x_test)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scores.append(r2_score(y_test,y_pred))
print(max(r2_scores))
print(np.argmax(r2_scores))
# Out:
# 0.9861939971252056
# 173

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np

best_r2 = -np.inf
best_degree = None
best_random_state = None

degrees = range(1, 10)  # try degrees from 1 to 9
random_states = range(0, 200)  # test random states from 0 to 199

for degree in degrees:
    for rs in random_states:
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=rs)
        poly = PolynomialFeatures(degree=degree)
        x_train_poly = poly.fit_transform(x_train)
        x_test_poly = poly.transform(x_test)

        model = LinearRegression()
        model.fit(x_train_poly, y_train)
        y_pred = model.predict(x_test_poly)

        r2 = r2_score(y_test, y_pred)

        if r2 > best_r2:
            best_r2 = r2
            best_degree = degree
            best_random_state = rs

print("Best R² Score:", best_r2)
print("Best Degree:", best_degree)
print("Best Random State:", best_random_state)
# Out:
# Best R² Score: 0.9861939971252056
# Best Degree: 8
# Best Random State: 173

# %%
df=pd.read_csv("placement.csv")
x=df[['cgpa','resume_score']]
poly=PolynomialFeatures(degree=3)
x=poly.fit_transform(x)
x
#to count features of x from degree (n+d)C(d) like nCr n=no. of features(x) d=no. of degree
# Out:
# array([[  1.      ,   8.14    ,   6.52    ,  66.2596  ,  53.0728  ,
#          42.5104  , 539.353144, 432.012592, 346.034656, 277.167808],
#        [  1.      ,   6.17    ,   5.17    ,  38.0689  ,  31.8989  ,
#          26.7289  , 234.885113, 196.816213, 164.917313, 138.188413],
#        [  1.      ,   8.27    ,   8.86    ,  68.3929  ,  73.2722  ,
#          78.4996  , 565.609283, 605.961094, 649.191692, 695.506456],
#        [  1.      ,   6.88    ,   7.27    ,  47.3344  ,  50.0176  ,
#          52.8529  , 325.660672, 344.121088, 363.627952, 384.240583],
#        [  1.      ,   7.52    ,   7.3     ,  56.5504  ,  54.896   ,
#          53.29    , 425.259008, 412.81792 , 400.7408  , 389.017   ],
#        [  1.      ,   8.77    ,   6.19    ,  76.9129  ,  54.2863  ,
#          38.3161  , 674.526133, 476.090851, 336.032197, 237.176659],
#        [  1.      ,   5.34    ,   7.09    ,  28.5156  ,  37.8606  ,
#          50.2681  , 152.273304, 202.175604, 268.431654, 356.400829],
# ...

# %%
poly.powers_
# Out:
# array([[0, 0],
#        [1, 0],
#        [0, 1],
#        [2, 0],
#        [1, 1],
#        [0, 2],
#        [3, 0],
#        [2, 1],
#        [1, 2],
#        [0, 3]], dtype=int64)

# %%
df=pd.read_csv("Fish.csv")
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
x=df['Species']

# %%
from sklearn.linear_model import LinearRegression
LinearRegression??
