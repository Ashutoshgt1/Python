# %%
import pandas as pd
ipl=pd.read_csv("ipl-matches.csv");
print(type(ipl))
print(ipl.loc[ipl['SuperOver']=='Y'])
print("-"*30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
print(ipl.loc[(ipl['City']=='Kolkata')&(ipl['WinningTeam']=='Chennai Super Kings')])

# %%
print(ipl.loc[(ipl['Player_of_Match']=='MS Dhoni')&((ipl['Team1']=='Mumbai Indians')|(ipl['Team2']=='Mumbai Indians'))])
# Out:
#          ID       City        Date Season        MatchNumber  \
# 630  548379  Bangalore  2012-05-23   2012  Elimination Final
#
#                    Team1           Team2                  Venue  \
# 630  Chennai Super Kings  Mumbai Indians  M Chinnaswamy Stadium
#
#          TossWinner TossDecision SuperOver          WinningTeam WonBy  Margin  \
# 630  Mumbai Indians        field         N  Chennai Super Kings  Runs    38.0
#
#     method Player_of_Match                                       Team1Players  \
# 630    NaN        MS Dhoni  ['M Vijay', 'MEK Hussey', 'SK Raina', 'S Badri...
#
#                                           Team2Players    Umpire1  \
# 630  ['SR Tendulkar', 'DR Smith', 'RG Sharma', 'KD ...  BF Bowden
#
#              Umpire2
# 630  HDPK Dharmasena

# %%
print(ipl.loc[(ipl['TossWinner']=='Gujarat Titans')&(ipl['TossDecision']=='bat')&(ipl['WinningTeam']=='Gujarat Titans')])
# Out:
#          ID         City        Date Season MatchNumber           Team1  \
# 17  1304103         Pune  2022-05-10   2022          57  Gujarat Titans
# 39  1304081  Navi Mumbai  2022-04-23   2022          35  Gujarat Titans
#
#                     Team2                                          Venue  \
# 17   Lucknow Super Giants  Maharashtra Cricket Association Stadium, Pune
# 39  Kolkata Knight Riders             Dr DY Patil Sports Academy, Mumbai
#
#         TossWinner TossDecision SuperOver     WinningTeam WonBy  Margin  \
# 17  Gujarat Titans          bat         N  Gujarat Titans  Runs    62.0
# 39  Gujarat Titans          bat         N  Gujarat Titans  Runs     8.0
#
#    method Player_of_Match                                       Team1Players  \
# 17    NaN    Shubman Gill  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# 39    NaN     Rashid Khan  ['WP Saha', 'Shubman Gill', 'HH Pandya', 'DA M...
#
# ...

# %%
print(ipl.loc[(ipl['TossWinner']=='Gujarat Titans')])
# Out:
#          ID         City        Date Season  MatchNumber  \
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 7   1304113       Mumbai  2022-05-19   2022           67
# 17  1304103         Pune  2022-05-10   2022           57
# 23  1304097       Mumbai  2022-05-06   2022           51
# 26  1304094  Navi Mumbai  2022-05-03   2022           48
# 34  1304086       Mumbai  2022-04-27   2022           40
# 39  1304081  Navi Mumbai  2022-04-23   2022           35
# 45  1304075         Pune  2022-04-17   2022           29
# 58  1304062       Mumbai  2022-04-08   2022           16
# 70  1304050       Mumbai  2022-03-28   2022            4
#
#                    Team1                        Team2  \
# 3       Rajasthan Royals               Gujarat Titans
# 7         Gujarat Titans  Royal Challengers Bangalore
# 17        Gujarat Titans         Lucknow Super Giants
# 23        Mumbai Indians               Gujarat Titans
# 26        Gujarat Titans                 Punjab Kings
# ...

# %%
#pb-88
df=pd.read_csv('supermarket_sales (1).csv');
df.loc[0:7]
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
# ...

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       4
# gross margin percentage    0
# gross income               0
# Rating                     5
# dtype: int64

# %%
df['cogs'].fillna(df['cogs'].mean(),inplace=True)
df['Rating'].fillna(df['Rating'].mean(),inplace=True)

# %%
q=df.loc[(df['Quantity']<3)&((df['Rating']>8.5)|(df['Total']>600))]
len(q)
# Out:
# 45

# %%
s=df.loc[df['Customer type']=='Member']
s['Total'].sum()
# Out:
# 164223.44400000002

# %%
s1=df.loc[df['Customer type']=='Normal']
s1['Total'].sum()
# Out:
# 158743.305

# %%
t=df['Total'].sum()
print(t)
e=df.loc[df['Payment']=='Ewallet']
print((e['Total'].sum()/t)*100)
# Out:
# 322966.74899999995
# 34.05709948177979

# %%
e=df.loc[df['Payment']=='Cash']
print((e['Total'].sum()/t)*100)
# Out:
# 34.74245269750665

# %%
e=df.loc[df['Payment']=='Credit card']
print((e['Total'].sum()/t)*100)
# Out:
# 31.200447820713578

# %%
print((df.loc[df['Payment']=='Credit card'])['Total'].sum()/t)
# Out:
# 0.3120044782071358

# %%
m=df.loc[df['Gender']=='Male']
print(m['Total'].sum()/len(m))
# Out:
# 310.7892264529058

# %%
f=df.loc[df['Gender']=='Female']
print(m['Total'].sum()/len(f))
# Out:
# 309.5485508982036

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Total'],df['Rating'],marker="+",color="green",s=100)

# %%
plt.boxplot((df['Rating'],df['Quantity']))
plt.show()
#there are no uotliers

# %%
# 8). Create a box plot that shows the distribution of ‘Rating’ and ‘Quantity’. And comment about outliers in both columns.
pd.plotting.parallel_coordinates(df,"Product line",cols=["Unit price",'Total','cogs'])
plt.show()

# %%
# 9). Visualize with parallel co-ordinates for ‘Unit price’, ‘Total’, ’cogs’ columns’ data with respect to ‘Product line’.
pd.plotting.scatter_matrix(df, figsize=[15,15])
plt.show()
